# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([{'product_id':23, 'name':'computer', 'wholesale_price': 500,
'retail_price':1000, 'sales':100},
{'product_id':96, 'name':'Python Workout', 'wholesale_price': 35,
'retail_price':75, 'sales':1000},
{'product_id':97, 'name':'Pandas Workout', 'wholesale_price': 35,
'retail_price':75, 'sales':500},
{'product_id':15, 'name':'banana', 'wholesale_price': 0.5,
'retail_price':1, 'sales':200},
{'product_id':87, 'name':'sandwich', 'wholesale_price': 3,
'retail_price':5, 'sales':300},
])

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price  sales
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300

# %%
df["sales"].sum()
# Out:
# 2100

# %%
df['current_net'] = ((df['retail_price'] - df['wholesale_price'])
* df['sales'])

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price  sales  \
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300
#
#    current_net
# 0      50000.0
# 1      40000.0
# 2      20000.0
# 3        100.0
# 4        600.0

# %%
df["15% tax"] = df["current_net"] * 0.85
df["20% tax"] = df["current_net"] * 0.8
df["25% tax"] = df["current_net"] * 0.75

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price  sales  \
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0
# 3        100.0     85.0     80.0     75.0
# 4        600.0    510.0    480.0    450.0

# %%
df.loc[df['wholesale_price'] > 30]
# Out:
#    product_id            name  wholesale_price  retail_price  sales  \
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price  sales  \
# 0          23        computer            500.0          1000    100
# 1          96  Python Workout             35.0            75   1000
# 2          97  Pandas Workout             35.0            75    500
# 3          15          banana              0.5             1    200
# 4          87        sandwich              3.0             5    300
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0
# 3        100.0     85.0     80.0     75.0
# 4        600.0    510.0    480.0    450.0

# %%
new_data = ([
 {"product_id": 16, "name": "Phone", "wholesale_price": 200, "retail_price": 500},
    {"product_id": 24, "name": "Apple", "wholesale_price": 0.5, "retail_price": 1},
    {"product_id": 117, "name": "Pear", "wholesale_price": 0.6, "retail_price": 1.2},
])

# %%
new_df = pd.DataFrame(data=new_data)

# %%
df = pd.concat([df, new_df], ignore_index=True)

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price   sales  \
# 0          23        computer            500.0        1000.0   100.0
# 1          96  Python Workout             35.0          75.0  1000.0
# 2          97  Pandas Workout             35.0          75.0   500.0
# 3          15          banana              0.5           1.0   200.0
# 4          87        sandwich              3.0           5.0   300.0
# 5          16           Phone            200.0         500.0     NaN
# 6          24           Apple              0.5           1.0     NaN
# 7         117            Pear              0.6           1.2     NaN
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0
# 3        100.0     85.0     80.0     75.0
# 4        600.0    510.0    480.0    450.0
# 5          NaN      NaN      NaN      NaN
# 6          NaN      NaN      NaN      NaN
# 7          NaN      NaN      NaN      NaN

# %%
df["product_id"].is_unique
# Out:
# True

# %%
df.loc[[5, 6, 7], "sales"] = [100, 99, 98]

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price   sales  \
# 0          23        computer            500.0        1000.0   100.0
# 1          96  Python Workout             35.0          75.0  1000.0
# 2          97  Pandas Workout             35.0          75.0   500.0
# 3          15          banana              0.5           1.0   200.0
# 4          87        sandwich              3.0           5.0   300.0
# 5          16           Phone            200.0         500.0   100.0
# 6          24           Apple              0.5           1.0    99.0
# 7         117            Pear              0.6           1.2    98.0
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0
# 3        100.0     85.0     80.0     75.0
# 4        600.0    510.0    480.0    450.0
# 5          NaN      NaN      NaN      NaN
# 6          NaN      NaN      NaN      NaN
# 7          NaN      NaN      NaN      NaN

# %%
(df['retail_price'] - df['wholesale_price']) * df['sales'].sum()
# Out:
# 0    1198500.0
# 1      95880.0
# 2      95880.0
# 3       1198.5
# 4       4794.0
# 5     719100.0
# 6       1198.5
# 7       1438.2
# dtype: float64

# %%
df
# Out:
#    product_id            name  wholesale_price  retail_price   sales  \
# 0          23        computer            500.0        1000.0   100.0
# 1          96  Python Workout             35.0          75.0  1000.0
# 2          97  Pandas Workout             35.0          75.0   500.0
# 3          15          banana              0.5           1.0   200.0
# 4          87        sandwich              3.0           5.0   300.0
# 5          16           Phone            200.0         500.0   100.0
# 6          24           Apple              0.5           1.0    99.0
# 7         117            Pear              0.6           1.2    98.0
#
#    current_net  15% tax  20% tax  25% tax
# 0      50000.0  42500.0  40000.0  37500.0
# 1      40000.0  34000.0  32000.0  30000.0
# 2      20000.0  17000.0  16000.0  15000.0
# 3        100.0     85.0     80.0     75.0
# 4        600.0    510.0    480.0    450.0
# 5          NaN      NaN      NaN      NaN
# 6          NaN      NaN      NaN      NaN
# 7          NaN      NaN      NaN      NaN

# %%
df.describe()
# Out:
#        product_id  wholesale_price  retail_price        sales   current_net  \
# count    8.000000         8.000000      8.000000     8.000000      5.000000
# mean    59.375000        96.825000    207.275000   299.625000  22140.000000
# std     43.533033       176.254368    362.052687   316.499577  22635.547265
# min     15.000000         0.500000      1.000000    98.000000    100.000000
# 25%     21.250000         0.575000      1.150000    99.750000    600.000000
# 50%     55.500000        19.000000     40.000000   150.000000  20000.000000
# 75%     96.250000        76.250000    181.250000   350.000000  40000.000000
# max    117.000000       500.000000   1000.000000  1000.000000  50000.000000
#
#             15% tax       20% tax       25% tax
# count      5.000000      5.000000      5.000000
# mean   18819.000000  17712.000000  16605.000000
# std    19240.215176  18108.437812  16976.660449
# min       85.000000     80.000000     75.000000
# 25%      510.000000    480.000000    450.000000
# 50%    17000.000000  16000.000000  15000.000000
# 75%    34000.000000  32000.000000  30000.000000
# max    42500.000000  40000.000000  37500.000000

# %%
mean_sales = df["sales"].mean()
df.query(f'sales > {mean_sales}')[['product_id', 'name']]
# Out:
#    product_id            name
# 1          96  Python Workout
# 2          97  Pandas Workout
# 4          87        sandwich

# %%
df.loc[df['sales'] > df["sales"].mean(), ['product_id', 'name']]
# Out:
#    product_id            name
# 1          96  Python Workout
# 2          97  Pandas Workout
# 4          87        sandwich
