# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"key1" : ["a", "a", None, "b", "b", "a", None], "key2" : pd.Series([1, 2, 1, 2, 1, None, 1], dtype="Int64"), "data1" : np.random.standard_normal(7),"data2" : np.random.standard_normal(7)})

# %%
df
# Out:
#    key1  key2     data1     data2
# 0     a     1  0.229505  1.412237
# 1     a     2 -1.472045 -0.885562
# 2  None     1 -0.810001 -0.556242
# 3     b     2 -1.344890 -0.028088
# 4     b     1  1.064973 -0.038527
# 5     a  <NA>  0.472690  0.981385
# 6  None     1  0.264870  0.213648

# %%
df['data1'].groupby(df['key1']).mean()
# Out:
# key1
# a   -0.256617
# b   -0.139959
# Name: data1, dtype: float64

# %%
df['data1'].groupby([df['key1'], df['key2']]).mean()
# Out:
# key1  key2
# a     1       0.229505
#       2      -1.472045
# b     1       1.064973
#       2      -1.344890
# Name: data1, dtype: float64

# %%
states = np.array(["OH", "CA", "CA", "OH", "OH", "CA", "OH"])
years = [2005, 2005, 2006, 2005, 2006, 2005, 2006]

# %%
df['data1'].groupby([states, years]).mean()
# Out:
# CA  2005   -0.499678
#     2006   -0.810001
# OH  2005   -0.557693
#     2006    0.664922
# Name: data1, dtype: float64

# %%
people = pd.DataFrame(np.random.standard_normal((5, 5)), columns=["a", "b", "c", "d", "e"], index=["Joe", "Steve", "Wanda", "Jill", "Trey"])

# %%
people
# Out:
#               a         b         c         d         e
# Joe   -0.786771  0.417266  0.302016 -0.529696 -1.094685
# Steve -0.460659 -0.469844  0.007331  1.123477  2.759453
# Wanda  0.299045 -1.908454  0.251115  1.172657  0.630328
# Jill  -1.275562 -1.140093 -0.183966  0.716284 -1.484102
# Trey  -0.348726  1.095336 -0.227862 -1.991023  0.131151

# %%
people.iloc[2:3, [1, 2]] = np.nan

# %%
mapping = {"a": "red", "b": "red", "c": "blue","d": "blue", "e": "red", "f" : "orange"}
mapping
# Out:
# {'a': 'red', 'b': 'red', 'c': 'blue', 'd': 'blue', 'e': 'red', 'f': 'orange'}

# %%
by_column = people.groupby(mapping, axis="columns")
by_column.sum()
# Out:
# <ipython-input-21-acba1b50385d>:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   by_column = people.groupby(mapping, axis="columns")
#            blue       red
# Joe   -0.227681 -1.464190
# Steve  1.130809  1.828950
# Wanda  1.172657  0.929373
# Jill   0.532318 -3.899757
# Trey  -2.218885  0.877761

# %%
people.groupby(len).sum()
# Out:
#           a         b         c         d         e
# 3 -0.786771  0.417266  0.302016 -0.529696 -1.094685
# 4 -1.624288 -0.044757 -0.411828 -1.274738 -1.352951
# 5 -0.161614 -0.469844  0.007331  2.296134  3.389781

# %%
df.groupby('key1')['data1'].nsmallest(2)
# Out:
# key1
# a     1   -1.472045
#       0    0.229505
# b     3   -1.344890
#       4    1.064973
# Name: data1, dtype: float64

# %%
df.groupby('key1')['data1'].describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# key1
# a       3.0 -0.256617  1.059591 -1.472045 -0.621270  0.229505  0.351097
# b       2.0 -0.139959  1.704031 -1.344890 -0.742424 -0.139959  0.462507
#
#            max
# key1
# a     0.472690
# b     1.064973
