# %%
import pandas as pd
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/data/sat-scores.csv",
                 usecols=["Year", "State.Code", "Total.Math", "Family Income.Less than 20k.Math", "Family Income.Between 20-40k.Math",
                         "Family Income.Between 40-60k.Math", "Family Income.Between 60-80k.Math", "Family Income.Between 80-100k.Math", "Family Income.More than 100k.Math"])

# %%
df
# Out:
#      Year State.Code  Total.Math  Family Income.Between 20-40k.Math  \
# 0    2005         AL         559                                513
# 1    2005         AK         519                                492
# 2    2005         AZ         530                                498
# 3    2005         AR         552                                513
# 4    2005         CA         522                                477
# ..    ...        ...         ...                                ...
# 572  2015         VA         517                                469
# 573  2015         WA         511                                483
# 574  2015         WV         500                                468
# 575  2015         WI         606                                551
# 576  2015         WY         587                                533
#
#      Family Income.Between 40-60k.Math  Family Income.Between 60-80k.Math  \
# 0                                  539                                550
# ...

# %%
df.describe().mean().sort_values()
# Out:
# Family Income.Less than 20k.Math       389.997998
# Family Income.Between 20-40k.Math      408.461977
# Family Income.More than 100k.Math      440.245740
# Family Income.Between 60-80k.Math      454.139328
# Family Income.Between 40-60k.Math      464.865426
# Total.Math                             470.356807
# Family Income.Between 80-100k.Math     479.928076
# Year                                  1580.023586
# dtype: float64

# %%
df.groupby("Year")[["Family Income.Between 20-40k.Math", "Family Income.Between 40-60k.Math",
                    "Family Income.Between 60-80k.Math", "Family Income.Less than 20k.Math", "Family Income.More than 100k.Math"]].mean()
# Out:
#       Family Income.Between 20-40k.Math  Family Income.Between 40-60k.Math  \
# Year
# 2005                         488.653846                         522.673077
# 2006                         502.923077                         523.769231
# 2007                         494.849057                         519.490566
# 2008                         523.622642                         547.471698
# 2009                         527.823529                         550.980392
# 2010                         499.274510                         522.000000
# 2011                         494.886792                         513.415094
# 2012                         492.056604                         512.452830
# 2013                         490.132075                         511.377358
# 2014                         497.641509                         514.943396
# 2015                         491.603774                         513.754717
#
# ...

# %%
df.groupby("Year")[["Family Income.Between 20-40k.Math", "Family Income.Between 40-60k.Math",
                    "Family Income.Between 60-80k.Math", "Family Income.Less than 20k.Math", "Family Income.More than 100k.Math"]].expanding().mean()
# Out:
#           Family Income.Between 20-40k.Math  \
# Year
# 2005 0                           513.000000
#      1                           502.500000
#      2                           501.000000
#      3                           504.000000
#      4                           498.600000
# ...                                     ...
# 2015 572                         490.204082
#      573                         490.060000
#      574                         489.627451
#      575                         490.807692
#      576                         491.603774
#
#           Family Income.Between 40-60k.Math  \
# Year
# 2005 0                           539.000000
#      1                           528.000000
#      2                           525.333333
#      3                           529.750000
#      4                           525.000000
# ...                                     ...
# 2015 572                         512.183673
#      573                         512.000000
# ...

# %%
df.groupby('Year').mean(numeric_only=True).sort_index()
# Out:
#       Total.Math  Family Income.Between 20-40k.Math  \
# Year
# 2005  535.653846                         488.653846
# 2006  537.480769                         502.923077
# 2007  535.339623                         494.849057
# 2008  535.981132                         523.622642
# 2009  540.803922                         527.823529
# 2010  540.843137                         499.274510
# 2011  533.226415                         494.886792
# 2012  533.603774                         492.056604
# 2013  532.622642                         490.132075
# 2014  534.283019                         497.641509
# 2015  533.094340                         491.603774
#
#       Family Income.Between 40-60k.Math  Family Income.Between 60-80k.Math  \
# Year
# 2005                         522.673077                         536.076923
# 2006                         523.769231                         534.903846
# 2007                         519.490566                         533.188679
# ...
